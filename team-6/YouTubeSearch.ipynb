# %%
#This function does a direct query to OpenAI
#It shows that without context, not much is returned on some topics

import openai
from dotenv import load_dotenv
import os

load_dotenv()

openai_api_key=os.getenv("OPENAI_API_KEY")
youtube_api_key=os.getenv("YOUTUBE_API_KEY")


# Initialize client using the new API interface
client = openai.OpenAI(api_key=openai_api_key)

# Define the prompt
prompt = "What does Nathan Babcock say about quantum effects in biology?"

# Make the request using the `chat.completions.create` method
response = client.chat.completions.create(
    model="gpt-4",  # Or "gpt-3.5-turbo"
    messages=[
        {"role": "user", "content": prompt}
    ],
    temperature=0.7,
    max_tokens=100
)

# Print the response
print("Response:", response.choices[0].message.content)
# Out:
# Response: I'm sorry, but I couldn't find any information on a person named Nathan Babcock discussing quantum effects in biology. It's possible that you may have misspelled the name or the person you're asking about isn't widely recognized in this field.

# %%
# Retrieve the transcript from a YouTube video. 
# Includes some exception handling

from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import (
    TranscriptsDisabled,
    NoTranscriptFound,
    VideoUnavailable,
    CouldNotRetrieveTranscript,
)

# YouTube Video ID
video_id = "1igKzDiWc84"

# Function to get transcript safely
def get_transcript_safe(video_id):
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        print(f"\nTranscript for video ID {video_id}:\n")
        for entry in transcript:
            print(entry['text'])
        return transcript
    except VideoUnavailable:
        print(f"❌ Video {video_id} is unavailable.")
    except TranscriptsDisabled:
        print(f"❌ Transcripts are disabled for video {video_id}.")
    except NoTranscriptFound:
        print(f"❌ No transcript found for video {video_id}.")
    except CouldNotRetrieveTranscript:
        print(f"❌ Could not retrieve transcript for video {video_id}.")
    except Exception as e:
        print(f"❌ An unexpected error occurred: {str(e)}")
    return None

# Run the function
transcript = get_transcript_safe(video_id)
# Out:
# Transcript for video ID 1igKzDiWc84:
#
# This is physical principles of quantum
# biology part one chapter 1 quantum
# theory and the new
# observables. For those of you who are
# new to the subject, I've recently
# released a monograph with my wife and
# collaborator Brandy Babcock on the
# physical principles of quantum biology.
# The book contains 21 chapters and these
# videos will provide lecture material
# outlining the content of each chapter.
# You can download the book for free from
# the physics archive. That's
# archive.org. Entry number
# 25503.11747. So go ahead, check it out.
# The book begins in chapter 1 with an
# overview of quantum mechanics starting
# in the year 1900 when Lord Calvin
# delivered a address to the Royal
# Institution outlining two major problems
# he saw in physics. He described these
# metaphorically as clouds hanging over
# the horizon of physics which he felt
# obscured the beauty and clearness of the
# dynamical theory so to speak. The first
# cloud was that of the luminiferous
# ether. uh Michaelelsson and Morley had
# performed an experiment that failed to
# detect Earth's movement through the
# luminiferous ether which was believed at
# the time to carry waves of light. Uh but
# the inability to detect the so-called
# ether which carried light waves
# electromagnetic waves through our
# universe uh posed a problem in terms of
# the question of what would carry
# electromagnetic waves if there was no
# such ether to detect. The second cloud
# uh concerns something called the
# equipartition principle. Uh the Maxwell
# Boltzman equipartition theorem uh was
# used to carry out certain calculations
# in thermodynamics predict things like
# the heat capacities of solids. It worked
# at high temperatures but failed
# miserably at low temperatures. And the
# question remained is what was wrong with
# the equipartician principle uh which
# Kelvin himself did not trust.
# So these concerns kind of uh became uh
# increasingly important as the years
# progressed after 1900. Uh Einstein
# proposed an explanation for the
# photoelectric effect and there was a
# growing understanding that the old
# classical theory was not going to work
# to describe a number of um emerging
# phenomena in physics. Uh so uh prominent
# chemist Nurse proposed that the leading
# physicists and some chemists should
# address this theoretical problem. Uh
# growing crisis as he called it and the
# industrialist Ernst SV uh held a
# conference in 1911 on radiation and the
# quanta. Uh now
# the participants in this conference as
# you can see in the attached photo
# included famous individuals like
# Einstein, Rutherford, uh Mary Cury and
# you can see uh SV himself in the lower
# left corner with the Colonel Sanders
# style mustache and goatee. Uh now
# ultimately it was resolved as a result
# of this conference that a new
# theoretical framework would be needed uh
# for a vast reform of the fundamental
# classical theories of the
# time. Work on this continued after the
# conference and in fact salv conferences
# were so successful they continue to be
# held to this day. uh but uh throughout
# the course of the next decade and
# through until 1925
# uh continuing work was developed on this
# so-called quantum theory um which in
# many ways culminated with the
# development of
# Heisenberg's quantum mechanics matrix
# mechanics um which he published in its
# earliest form in a paper he wrote in
# 1925 Heisenberg's key insight uh which
# allowed the development of the old
# quantum quum theory as it was called
# into what is now still modern quantum
# mechanics. Uh his trick was to focus
# only on observables, things that could
# conclusively be measured and counted in
# numbers. He based the new theory
# entirely on relationships between
# measurable quantities. And the reason
# why was because at that time they were
# trying to figure out the orbit of
# electrons around the nucleus in an atom.
# Uh but they couldn't measure the
# electron traveling in a circular orbit.
# the way we can observe the planets
# orbiting around the sun and eventually
# Heisenberg thought he must dispense with
# the idea of measurable orbits with well-
# definfined position and momenta
# entirely. Uh the consequence was the
# formation of a new matrix mechanics a
# mathematical approach that was later
# confirmed uh to be equivalent to an
# operator algebra developed by direct and
# of course shinger's famous wave
# mechanics and this uh ultimately
# resulted in a major paradigm shift in
# the thinking of u physicists and
# certainly the founders of quantum
# mechanics who didn't know what to make
# of it at first uh by eliminating
# references to any unobserved observable
# quantities from any physical
# theories. So what is this quantum
# theory? Well, the modern framework
# quantum mechanics today is based uh
# primarily on four postulates. These are
# the four standard postulates you should
# see in any standard quantum mechanics
# textbook which involve the definition of
# a quantum state in a mathematical
# framework. It's known as a Hilbert
# space. So this quantum state is a vector
# on a Hbert space. We can propose a
# so-called unitary that is reversible
# evolution of the state according to the
# Schroinger equation Schroinger wave
# mechanics of course and the postulate
# that observables are all hermission.
# This is a special type of mathematical
# symmetry that guarantees that the
# outcomes of any measurements in our
# mathematical calculus will all be
# described by real
# numbers. Uh these are sometimes also
# known as self adjoint operators.
# Although there's a technical issue there
# I won't get into. Uh finally the key
# point is that measurements are
# probabilistic. We may not be able to
# know for sure the outcome of a given
# measurement. Uh but we can predict the
# probability of those outcomes using a
# mathematical tool known as Borne's rule.
# Uh Borne's probability rule. And this
# allows us to predict if not with
# certainty not deterministically the
# outcomes of measurements. we know with
# some certainty what the probabilities of
# certain measurement outcomes should be.
# Now this is textbook quantum mechanics.
# Uh this is everything you need at the
# most basic levels to do textbook quantum
# mechanics. Uh but of course it says
# nothing about bzons or firmians uh
# symmetriized or so-called anti-ymmetized
# states. It doesn't give us quantum field
# theory and it certainly is in no state
# to reconcile the theory of quantum
# mechanics with something like gravity.
# Uh so even though this is textbook
# mechanic quantum mechanics in its closed
# form, of course the theory is um you
# know only limited to the very specific
# set of cases that it itself can describe
# at a textbook kind of level. And as we
# proceed through the lecture, we're going
# to see what the limitations of this very
# well-defined uh very accurate but
# ultimately limited
# theory. So here we are. What are the
# limits of orthodox quantum theory? Well,
# if Lord Calvin was around today, I think
# he would have similar concerns, he might
# even propose a third cloud hanging over
# the horizon of physics today. Now,
# Calvin was adamant in his view echoed by
# quantum theory uh that unless you can
# put a number on your knowledge that your
# knowledge is of a meager and
# unsatisfactory kind. uh this is kind of
# a preliminary to um Heisenberg's idea
# that all physical quantities must be
# observable and if we can make
# measurements we can express those
# measurements in numbers. So in many way
# Heisenberg's theory was a direct
# consequence of an idea that Kelvin had
# proposed the previous century. Now what
# is interesting about this is if you look
# back at the old dialogues uh between
# Dyra and Heisenberg for example they had
# their views about what really comprised
# a theory um or what a theory should be
# composed of and Durk felt that theory
# should be open and uh subject to
# revision whereas Heisenberg thought no
# once you have a theory it should be
# closed and complete in the sense that
# that theory's uh domain applicability
# should be clearly defined and if there
# were future discoveries or revolutions
# in physics, it wouldn't be a
# modification to the old theory. It would
# be in fact the creation of a whole new
# theory with a new domain. Uh so they
# didn't really agree on what a theory
# should be open or closed. But one thing
# they could agree on uh was that the
# development of quantum theory should not
# make use of classical mechanics. And in
# fact uh Heisenberg was adamant that new
# phenomena require the formation of a new
# closed theory. Uh so the real issue here
# if we now look a little more closely at
# what is really entailed in quantum
# mechanics is that we have this postulate
# about measurement that requires the
# existence of a measurement device. And
# unfortunately for quantum theory or for
# our conceptualization of quantum theory,
# the measurement device itself is not
# described by quantum mechanics either
# then in the 1920s or even today. Uh
# quantum mechanics fails to describe the
# measurement apparatus itself. And we
# have to assume that the apparatus or the
# experimenters doing the measurement are
# somehow classical objects. Even though
# of course uh laboratories and apparatus
# and experimenters are all made of the
# same atoms, electrons, nuclei and so
# forth that uh we have in our quantum
# physics experiments themselves. So
# there's a kind of incompleteness in
# quantum mechanics due to the fact that
# we have these beautiful postulates that
# define the mathematics of quantum theory
# in this abstract sense. But in order to
# actually predict results of our
# calculations, we need to add this
# classical measuring apparatus in by
# hand. And uh this kind of ad hoc
# addition to the theory has been very
# troubling to physicists throughout the
# decades since quantum mechanics was
# developed. Of course uh quantum
# mechanics has still has problems in
# terms of its relationship to relativity.
# um we have uh some versions of quantum
# electronamics uh that are compatible
# with relativity but to go to full-blown
# quantum gravity uh of course this is
# still a major open project uh a grand
# challenge in physics and so this
# measurement problem this idea that we
# have a quantum system that evolves
# unitarily in time uh we can predict uh
# certain expectation values you know
# certain
# um likely results or average results of
# of the experiments we perform on these
# quantum systems all still hinges on the
# existence of this seemingly classical
# device uh that can somehow collapse the
# wave function so to speak to get this
# probabilistic superposition of possible
# outcomes narrowed down to a single
# actual outcome that we observe during
# any experimental setup.
# So there's a real divide between the
# quantum and classical realms. Quantum
# mechanics and classical physics are in
# some way incompatible even though we
# think on at least in some limit. One
# theory should be a special case of the
# other. Classical phenomena are assumed
# to emerge from underlying quantum
# systems as you add more and more atoms
# and the system gets bigger as you
# approach the macroscopic limit. And this
# assumption is known as the
# correspondence principle that on some
# level quantum phenomena should
# correspond to macroscopic classical
# effects. However, quantum mechanics as
# I've mentioned is incomplete without
# classical theory. We have to
# assume classical measuring devices in
# order to carry out our measurement
# calculus and predict the results of our
# experiments. Uh so rather than being
# able to derive classical physics from
# quantum theory as the founders of
# quantum mechanics like bore and
# Heisenberg expected classical theory is
# a required a prerequisite of quantum
# mechanics and this from a theoretical
# point of view is very problematic. If
# you look at Einstein's relativity for
# example, uh Newtonian physics, uh
# Newtonian kinematics are a special case
# of Einstein's special relativity and the
# limit where things move slowly. Uh but
# the limit where things get big enough
# that quantum systems become classical
# has still never actually been formally
# mathematically defined with any rigor.
# And so we still have this enormous gap
# between the quantum and classical which
# has not been bridged in anything but a
# kind of um ad hoc uh speculative sense.
# Now we know that quantum systems are
# quantum and classical systems are
# classical but where we draw the line is
# unclear and in fact that line drawing
# step is known as the Heisenberg cut. um
# which in some view some people's view is
# completely
# arbitrary. But we can think of systems
# that bridge the gap between quantum and
# classical. Uh classical systems uh
# according to one estimate by Bassie and
# co-workers in the review of modern
# physics uh can be trusted. uh classical
# systems we see uh for objects on the
# scale of um micrograms or larger uh
# objects as heavy as 10 the 6 g or
# bigger. Whereas quantum effects can be
# expected
# to ultimately uh govern the dynamics of
# our system for very small objects on the
# scale of uh about a zepptogram or less.
# That's 10 ^ of -21 g. So for a
# physicist, you can see right away there
# are 15 orders of magnitude gap between
# the kinds of systems we can treat as
# decisively classical and the kind of
# systems that we should consider
# unequivocably quantum. And so the
# question of how to negotiate this
# quantum classical divide as I mentioned
# is still unanswered. Uh the physicist
# just does this division in his mind. Uh
# separating
# the quantum system under study from the
# classical laboratory apparatus, the
# knobs he turns and buttons he presses.
# And this uh artificial separation, the
# Heisenberg cut so to speak, is good
# enough for most of our applications when
# we clearly know in our laboratory the
# difference between the system we're
# studying and the seemingly classical
# apparatus that we use to study it. Now,
# one of the reasons I became interested
# in biology was because of course biology
# a priority from first principles has no
# such artificial boundary. If we look at
# the scale from zepptograms to
# micrograms, uh, biological systems,
# living organisms have stuff going on at
# every scale all the way from individual
# molecules and, uh, things like DNA,
# genes, uh, ATP, other individual
# biological molecules scaling up to
# macroolelecules like proteins, organels,
# various components of the cells, and
# ultimately tissue. issues. Uh biological
# complexity exists on every scale. So
# living systems have seen no need to
# perform an artificial Heisenberg cut. Uh
# they literally have things going on all
# the way down or all the way up if you
# start from first principles.
# Now beginning from first principles uh
# Schroinger for example in the 1940
# claimed that classical physics would be
# fundamentally inadequate to understand
# molecular biology and living processes
# because once you go down to the micro
# micro microscopic scale, statistical
# fluctuations naturally destroy classical
# order. And this is interesting
# especially because recently um you know
# some critics of quantum biology have uh
# claimed that decoherence the same kind
# of random fluctuation should destroy
# quantum mechanical coherence at this
# scale. Uh but the problem with this
# argument is it applies just as well to
# classical order as it does to quantum
# order. And so the real question is why
# biological order should exist at all. Uh
# so Schwinger really argued forcefully in
# his claim that the classical physicist's
# expectation about biology far from being
# trivial is wrong that we really cannot
# even hope classical mechanics to explain
# biology at the molecular level and we
# must understand how quantum mechanics
# preserves this coherence as you scale
# from the quantum scale all the way up to
# the classical. uh now similar ideas were
# developed uh by uh another Nobel prize
# winner St. Georgie who proposed that
# deoized common energy levels must be
# necessary in biological molecules to
# explain their unique catalytic
# properties in enzymes for example. And
# if you uh read his paper toward a new
# biochemistry in 1941 he had already
# proposed that electronic deoization was
# very important for certain biological
# processes. Um we now know uh electronic
# deoization is critical even for the
# structure of biomolelecules. If you've
# ever studied organic chemistry or um
# taken a aromatherapy course even uh
# these aromatic molecules uh their whole
# existence and many of their wonderful
# numerous properties depend on the
# electronic deoization of the molecules
# themselves. Uh now this idea that
# uh deoized electrons form common energy
# bands like we see in semiconductors uh
# didn't really see formal development
# until the advent of Marcus theory in the
# 1950s. Uh now Marcus identified how the
# complexity of electron transfer
# reactions in chemistry depended on a
# number of factors including energy
# conservation solvent dynamics and
# ultimately in the decades of work he put
# in from the 50s to the 80s uh so-called
# non-abatic quantum effects and these
# non-indabatic quantum effects that he
# considered in his 1984 paper on the
# subject uh really explained the key role
# of quantum mechanics and what should
# otherwise be a simple chemical reaction,
# just an electron being transferred from
# one molecule to another. And now we know
# in fact that for the most part these
# electron transfer reactions occur as a
# result of electron tunneling. As uh
# Winkler Gray and other colleagues
# conclusively identified biological
# electron tunneling in cytochrome C in
# the early 80s and uh we now know that
# electron tunneling is essential for many
# aspects of cellular respiration and
# other metabolic chemical reactions in
# living cells.
# So my view is that if we approach
# biology from first principles, we can
# learn new things not just about biology
# but also potentially physics.
# Now, a lot of work in quantum biology
# approaches biology from classical
# assumptions, classical biology, and then
# proposes to find effects that violate
# classical physics and say give organisms
# some selective advantage in order to
# identify possible so-called non-trivial
# effects, quantum effects in biology. Uh
# but my view is that even when this
# approach is used at its best, it's
# essentially ad hoc because we're
# imagining a classical hay stack so to
# speak and going looking for quantum
# needles in it. Uh but really if we
# really believe quantum mechanics, we
# should begin with the quantum mechanical
# postulates first and then we can explore
# the full range of possible quantum
# states and effects at their most
# microscopic level at the level of atoms
# and molecules. And then as we scale up
# gradually introduce classical
# approximations only where necessary and
# appropriate rather than assuming our
# classical approximation first and then
# working backwards to find out where it's
# violated. Now don't get me wrong both
# approaches can work but my view is that
# the fundamental bottomup approach so to
# speak will enable biological systems to
# be investigated in a way that is more
# realistic and more accurate and
# ultimately more systematic for me as a
# physicist.
# So again what are these postulates? Well
# actually they emerged from fundamental
# principles of nature. Heisenberg
# famously developed his theory of matrix
# mechanics beginning in 1925 after he had
# an epiphany on the island of Heland and
# he proposed
# uh as he continued his work to the end
# of the 1920s and published a textbook on
# it in 1930. three basic principles in
# light of the correspondence principle.
# Again, this idea that on some level
# things that we observe on the quantum
# scale must correspond to things that we
# observe on the classical scale, things
# like position and momentum and energy.
# So, uh using the correspondence
# principle as his guide, he proposed that
# conservation of energy as it's expressed
# in the Ryberg Ritz combination principle
# shown in item number one here. uh the
# idea that the difference between uh one
# energy level and another energy level
# should be the same as the difference
# between either of those two energy
# levels and a third energy level. Uh now
# second he proposed as a basic principle
# the quantization of energy. If we want
# quantum theory, things must be
# quantized, which simply means that
# things like energy or angular momentum
# come in discrete little packets that we
# can label 1 2 3 4 up on to infinity. Uh
# the same way we might get single serving
# packets at the grocery store or on an
# airplane. Uh but the thing about these
# single serving packets is that they
# can't fundamentally be divided into
# smaller packets. These are the
# fundamental quanta of nature itself. Now
# third he based his uh theory on
# something called the bore frequency
# relation. And this is where uh in fact
# Max Planck's insight into quantum theory
# um you know really take hold this idea
# that there's a so-called fundamental
# quantum of action uh known as H plank's
# constant and that the relationship
# between the energy contained in a system
# where the difference between two
# energies of the system the energies of
# two different states of the system is
# proportional to some frequency and that
# the relationship between the energy And
# the frequency is given by a constant a
# constant of nature h known as plank's
# constant. So he took these three things
# conservation of energy quantization of
# energy and the bore frequency relation
# which emerged from the quantum of action
# and he used the correspondence principle
# to reason about how a quantum theory of
# mechanics should look based on what we
# already know about classical mechanics
# Newton's laws and the Hamiltonian
# principle and such. And from this he was
# able to effectively derive quantum
# mechanics in its textbook form as we
# still see it
# today. Now all of
# this in the form we see it today depends
# on this funny property called hermission
# symmetry. So this is a mathematical
# symmetry and in some sense the symmetry
# of nature that ensures the conservation
# of probabilities for example in our
# quantum system that probabilities should
# always add up to 100%. And if they don't
# that means something got lost but for a
# closed system
# the conservation of probability should
# be maintained. If I lock something in a
# safe, if I lock $1,000 in a safe, when I
# come back, all $1,000 should be there
# with 100% probability unless I was
# robbed. Right? Now, the mathematical
# expression for this hermission symmetry
# uh takes a unique form. If we have a
# hermission operator capital H, then we
# say it's equal to its hermission
# conjugate uh which is shown as uh
# superscript dagger attached to the
# letter. Uh so for something to have
# hermission symmetry it means that the
# operator the hermission operator capital
# H must equal its conjugate transpose H
# dagger. The physical significance of
# this funny mathematical property is it
# guarantees uh that the igen values the
# energy states of the system these
# discrete packets of
# energy are real uh they don't take on
# imaginary values and that if we use this
# uh hermission say Hamiltonian operator u
# to describe our dynamics the dynamics
# will be reversible that nothing is lost
# or gained and we could say play the tape
# of our dynamics of our system backwards,
# so to speak. The only thing with this,
# although it works very well in principle
# and it makes sense as a fundamental
# theory, is that when we look at reality,
# a lot of things aren't reversible. If I
# crack an egg, I can't put it back
# together again. As the older children's
# nursery rhyme says, all the king's
# horses and all the king's men couldn't
# put Humpty Dumpty back together again.
# And so, we see an arrow of time in our
# daily lives. uh that suggests that for
# many practical purposes this idea of
# hermission symmetry uh time reversal
# symmetry actually breaks down and in
# fact we now know uh that hermission
# symmetry is not as fundamental to
# quantum mechanics as it was once
# believed. Although hermission symmetry
# is sufficient to guarantee real values
# and reversible dynamics and systems,
# it's not necessary. There are now other
# symmetries that are coming to be
# understood such as another kind called
# parody time symmetry quantum mechanics.
# And so what was viewed as being one of
# the most fundamental symmetries of
# quantum theory is now becoming
# understanded as not even necessary.
# So we have this thing called non-
# hermission quantum theory that breaks
# from traditional quantum theory and
# these non- hermission systems can often
# exhibit remarkable properties uh that I
# believe in many cases are critical to
# living processes because of course
# living systems aren't closed systems.
# They have complex boundary conditions
# and uh things get lost. Things go in and
# out of living systems all the time. I
# have to breathe air in and breathe
# carbon dioxide out all the time to stay
# alive. So we don't have systems with
# conserved properties the way we like to
# think of them in conventional quantum
# mechanics. Now there are also phenomena
# called resonances uh that emerge in
# non-ermission open quantum systems
# theory uh which have a lot of
# significance in physics and potentially
# great significance in biology as well.
# uh certainly in chemistry uh resonances
# play a key role in our understanding of
# many molecular bonds and so forth. Now
# another interesting
# thing is the potential for directional
# transport in a non- hermission theory.
# So in a hermission dynamical theory uh
# all the dynamics are always reversible.
# Uh but what we really want to see if we
# study living things is uh directed
# transport where we have things go
# forward um but they can't go backward. I
# grow up uh but I can't unage myself. And
# so this so-called non reciprocity uh
# enables us to define energy flow in
# preferred directions and ultimately even
# the flow of time in the forward
# direction. Uh now finally open quantum
# systems uh exhibit complex or incomplete
# spectra due to coupling with the
# environment uh which make them very
# different from our usual study of
# hermission systems uh which are complete
# always in the formal sense um that
# Heisenberg for example uh considered
# necessary in order to describe
# uh mechanical system authoritatively. Uh
# so how could we make uh a complete
# theory of non-hermission quantum theory?
# Uh this is an open question and um in
# many ways uh non-ermission quantum
# mechanics uh can be simplified to
# hermission quantum theory through pseudo
# hermission operators and the like but uh
# that's a bit beyond the scope of this
# video today.
# Open quantum systems theory for
# biological sciences I think will be very
# be very helpful because unlike isolated
# quantum systems living organisms must
# continually interact with their
# surroundings to survive. And now
# paradoxically this environmental
# coupling preserves the quantum effects
# that are essential to sustain life that
# I have to eat and I have to breathe
# oxygen in order for the respiratory
# chain in my cells and my mitochondria to
# keep going. And if I stop breathing or I
# stop eating or even drinking water for
# long enough, I will die. And these
# quantum mechanical processes like
# electron transfer that enables
# respiration and other catalytic
# reactions that enable metabolism will
# stop. Uh so really we almost need to
# turn our picture of quantum theory on
# its head in order to understand uh how
# environmental coupling actually
# preserves the fundamental quantum
# effects that have been established
# in biology since the 80s if not earlier.
# Environmental coupling is necessary to
# maintain continual energy and
# information exchange with their
# surroundings. and the quantum coherence
# that's necessary for electron tunneling
# reactions and for uh other certain you
# know preparation of catalytic
# states. Biology has to find a way to
# preserve these things rather than
# destroying them. And biological systems
# really need to work on the right time
# scales in order to carry out certain
# reactions or electron transfer steps uh
# that are just the right speed um so that
# uh they're coherent enough for the
# reaction to occur but uh shall we say
# decoherent enough um for it to be
# directed not time reversal. uh this is
# all necessary to main order in
# biological systems and sustain the
# complexity of living systems and if uh
# you haven't hinted from what I'm
# suggesting so far this is all essential
# to maintaining kind of thermodynamic
# flow uh that the nonequilibrium
# properties of biology of course I'm not
# completely at rest even if I have a
# constant regulated body temperature I'm
# also constantly producing heat that's
# dissipated to my environment and uh
# Shortinger himself thought uh that the
# role of free energy or as he called it
# in his 19 uh 444 book what is life a
# negentropy is really the essential
# characteristic to understanding living
# systems. Now there's a lot of quantum
# mechanical models that are already used
# to study molecular biology. Um these
# systems even on the molecular scale can
# already be extraordinarily complex when
# we consider electronic states. uh if we
# look at the simulation methods that are
# already being used uh we begin with the
# Borne Oenheimer approximation which says
# that the nuclei and the electron uh
# orbiting around them so to speak can be
# considered separately that the nuclei
# can be considered essentially
# classically as classical point particles
# and the electrons can be considered as a
# kind of density um a uniform density or
# u perhaps a variable density around the
# nuclear state. But uh once we've solved
# for the electronic properties of the
# system around these seemingly classical
# nuclei, we can get all the properties
# out of the system. And this kind of
# picture of molecular biology or
# um really even simply chemistry is uh
# the cornerstone for approximation
# methods like density functional theory
# and heartry f theory where we olude only
# uh simple quantum exchange effects due
# to the fiatic nature of the electrons.
# Now, as things get more complicated, if
# we have an electron
# um undergoing a quantum jump tunneling
# from one molecule to another, we might
# need to take what's called a
# multifiguration approach where we need
# to consider different electronic
# configurations of the system that are
# only weekly coupled for example in a
# tunneling effect. And we might address
# this through perturbation methods which
# can get very complicated very quickly.
# uh now if we fail to satisfy the Borne
# Oppenheimer approximation we get into
# something called a nonadiabatic quantum
# mechanics and quantum dynamics and in
# this case we really are going to rely on
# um multi-reference uh multi
# configuration theories and even what are
# called uh coupled cluster methods uh
# where we begin to really consider the
# full complexity of the quantum
# mechanical system in question. And now
# if the quantum mechanical system is too
# complex uh to study the whole system at
# its full level of complexity, we might
# use what's called a quantum embedding
# approach where we uh find certain
# mathematical approximations in order to
# bed embed the full complexity of our
# quantum system of interest in its
# surroundings the surrounding solvent and
# protein protein where a classical or
# semiclass approximation might be
# appropriate. Uh now this can cover a lot
# of effects but it may not account for
# all of the uh dynamical effects uh due
# to interactions with the environment and
# dynamical mean field theories are often
# used now in order to account for uh
# certain more complex aspects of the
# system uh before going to full scale
# non-ermission quantum or greens function
# method uh which allows us to consider
# the full nature of the interaction of a
# system of interest with its quantum
# mechanical surroundings as
# well. So quantum mechanical modeling can
# be very complex for these systems and
# highly advanced methods have been
# developed for physics and chemistry
# simulations of this kind. Uh so right
# away if you're doing complex quantum
# mechanical calculations you may need a
# high performance computing architecture
# a supercomput if you will uh in order to
# do these large scale simulations and
# matrix diagonalizations to get our
# energies or IGEN values. Uh now often
# classical approximations can be good
# standins for quantum effects if we
# really understand the nature of the
# quantum effect we're studying but we
# don't always know the correct classical
# parameters to use to develop our
# simplified classical approximations. Uh
# so sometimes we can predict
# the parameters in our semi-class theory
# from first principles but other times we
# don't know what they are or they're too
# complex to calculate. And so machine
# learning methods have been used to find
# hidden symmetries of quantum mechanical
# problems in the hope of parameterizing
# effective classical potentials uh to
# treat otherwise quantum mechanical
# systems. uh now where these kind of uh
# semiclass or quantum mechanical
# approaches using classical computers
# fail, it's now being proposed that
# quantum computers may truly be necessary
# to address the computational complexity
# of studying things at the molecular
# scale in chemistry, materials, and of
# course biology.
# Some of the challenges for quantum
# biology as a quantum theory of biology
# are first of all the self interactions
# uh that exist in biological systems.
# Homeostasis the ability to self-regulate
# is a key feature of all biological
# systems. Uh but this kind of self-
# interaction has always been at at odds
# uh with the linear nature of textbook
# quantum mechanics. And now we have the
# measurement problem or perhaps I should
# say we don't have the measurement
# problem for living organisms because
# they don't have any classical measuring
# apparatus embedded in them. Living
# organisms in the most simple effects you
# know simple way don't go into
# laboratories and assume they have
# apparatus that are classical to study
# quantum mechanical effects. So in one
# way we've simply absolved ourselves of
# the so-called measurement quantum of
# problem measurement problem of quantum
# mechanics. But on the other hand, we
# really have to figure out how classical
# approximations emerge in biological
# systems if there's no a priority
# measurement devices to reduce things to
# classicality so to speak. And of course,
# the final problem is the enormous
# complexity of biological systems. Even
# classical biology is enormously complex.
# And these quantum effects are now
# embedded not in a sterilized laboratory
# environment but a rich thermal
# environment uh that can't be treated as
# completely being at equilibrium either.
# Uh so there's a lot of very interesting
# fundamental challenges that we face
# studying biological systems from quantum
# mechanical first
# principles and I believe that this kind
# of study can lead us to discovery even
# potentially of new fundamental physics.
# uh people like Schroinger and Neils
# Boore believed that new fundamental
# physics would come out of biology and I
# too believed that emerging discoveries
# may challenge the current scientific
# understanding of physics as well as
# biology. Uh so this vast reform of
# concepts that was originally proposed by
# nurst uh when he called the first salvey
# conference in 1911 continues today as we
# hope to bridge the gap between quantum
# classical worlds and to as we consider
# things like resonances and singularities
# uh which are fundamental to physics uh
# but sometimes challenging to describe
# mathematically in a linear theory like
# quantum mechanics.
# And my hope is as we gain greater
# insight and knowledge into these things
# uh that new physical principles may
# emerge uh to help us you know ultimately
# for example uh to quantify the meaning
# of the correspondence principle as well
# as other governing principles in
# physics. So what is the future re of
# research in quantum biology look like?
# Uh as I mentioned I hope we may discover
# undiscovered biological and physical
# phenomena. Uh we have hopes of
# developing quantum biotechnology
# uh that may use um biomimetic
# uh effects uh to enable sophisticated
# bioengineering and medical engineering.
# Uh my hope is that advanced biomedical
# applications will also alert emerge from
# quantum biology. uh the work we consider
# today may have significant implications
# for things like molecular electronics
# and even biological computing as well as
# potentially revolutionary applications
# in material and energy science. If we
# can understand some fundamental
# properties of enzymes which carry out
# reactions at terrestrial temperatures uh
# that we ourselves as human technologists
# need to perform at high temperatures and
# pressures. uh we may be able to produce
# revolutionary applications um with great
# industrial and commercial consequences.
# So please if you've enjoyed today's
# lecture check out physical principles of
# quantum biology you can download it from
# this abstract this uh website find the
# abstract and find the book downloaded if
# you're a researcher a student or just
# curious to venture beyond classical
# biological explanations and uh finally
# in conclusion if you have any questions
# don't hesitate to reach out again I'm
# Dr. be uh this is my email address and
# bababcock@gmail.com. You can check out
# other YouTube videos on my YouTube
# channel at drbabcock. And an enormous
# thanks go out to my wife Brandy Babcock
# and collaborator on the book physical
# principles of quantum biology and on the
# development of this slideshow today. Uh
# so thanks to you all finally for
# watching and have an excellent day.
# Cheers.

# %%
# This block searches for information found in the transcripts
# of a set of YouTube videos

# STEP 1: Search YouTube using video names
#         Provide a search term which will be used to find a
#         list of matching YouTube videos
# STEP 2: Get and Chunk Transcripts
#         Save the transcripts in a vector database
# STEP 3: Create FAISS Index
# 
# STEP 4: In a loop search for something within the transcripts
#         Query FAISS
#         The search is used to find blocks of text that are relevant
#         from the vector databases, to build context for OpenAI
# STEP 5: Query OpenAI
#         Peform a search using OpenAI and the context from the 
#         chunks retrieved from the Vector database

import googleapiclient.discovery
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import NoTranscriptFound
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
from openai import OpenAI

# ==== CONFIGURATION ====

CHUNK_SIZE = 500
TOP_K = 5

# ==== SETUP ====

client = OpenAI(api_key=openai_api_key)
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=youtube_api_key)
model = SentenceTransformer("all-MiniLM-L6-v2")

# ==== STEP 1: Search YouTube ====
def search_youtube_videos(query, max_results=5):
    request = youtube.search().list(
        q=query, part="snippet", type="video", maxResults=max_results
    )
    response = request.execute()
    videos = []
    for item in response["items"]:
        video_id = item["id"]["videoId"]
        title = item["snippet"]["title"]
        videos.append({"id": video_id, "title": title})
    return videos

# ==== STEP 2: Get and Chunk Transcripts ====
def get_transcript_chunks(video_id, chunk_size=500):
    try:
        # Request only English transcript
        transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['en'])

        chunks = []
        current = ""
        for entry in transcript:
            text = entry['text']
            if len(current) + len(text) <= chunk_size:
                current += " " + text
            else:
                chunks.append(current.strip())
                current = text
        if current:
            chunks.append(current.strip())

        return chunks

    except Exception as e:
        print(f"❌ Skipped video {video_id}: {e}")
        return []



# ==== STEP 3: Create FAISS Index ====
def build_faiss_index(chunks):
    embeddings = np.array([model.encode(chunk) for chunk in chunks])
    index = faiss.IndexFlatL2(embeddings.shape[1])
    index.add(embeddings)
    return index, embeddings

# ==== STEP 4: Query FAISS ====
def retrieve_relevant_chunks(query, index, chunks, top_k=TOP_K):
    query_embedding = model.encode(query).reshape(1, -1)
    distances, indices = index.search(query_embedding, top_k)
    return [chunks[i] for i in indices[0]]

# ==== STEP 5: Query OpenAI ====
def ask_openai(chunks):
    content = "\n\n".join(chunks)
    prompt = f"Analyze and answer based on the following transcript chunks:\n\n{content}"
    response = client.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "user", "content": prompt}
        ],
        temperature=0.5,
        max_tokens=1000
    )
    return response.choices[0].message.content

# ==== MAIN PROGRAM ====
def run_pipeline():
    topic = input("🔍 Enter a topic to search YouTube videos: ")
    videos = search_youtube_videos(topic)
    
    print("\n🎬 Found Videos:")
    for i, v in enumerate(videos, 1):
        print(f"{i}. {v['title']} (ID: {v['id']})")

    all_chunks = []
    for v in videos:
        print(f"\n⏳ Processing: {v['title']}")
        chunks = get_transcript_chunks(v["id"])
        if chunks:
            all_chunks.extend(chunks)

    if not all_chunks:
        print("❌ No usable transcripts found.")
        return

    print("\n📦 Building vector database...")
    index, _ = build_faiss_index(all_chunks)

    while True:
        query = input("\n❓ Ask a question about the topic (or type 'exit'): ")
        if query.lower() == "exit":
            break
        results = retrieve_relevant_chunks(query, index, all_chunks)
        print("\n🔍 Top Relevant Chunks:")
        for i, chunk in enumerate(results, 1):
            print(f"{i}. {chunk}\n")

        summary = ask_openai(results)
        print("\n🧠 OpenAI Summary:")
        print(summary)

# ==== Run it ====
if __name__ == "__main__":
    run_pipeline()
# Out:
# 🔍 Enter a topic to search YouTube videos:  Nathan Babcock Quantum Biology
# 🎬 Found Videos:
# 1. Quantum Theory &amp; The New Observables: Chapter 1 of Physical Principles of Quantum Biology (ID: 1igKzDiWc84)
# 2. Quantum Biology: From Photons to Physiology (ID: mf6lkIipjF0)
# 3. FULL LECTURE - Physical Foundations of Quantum Biology (ID: bRpTpSJFGCs)
# 4. A Template for Quantum Biology (ID: 9u7rIODg2YU)
# 5. Quantum Biology for Health and Medicine (Resonance Symposium, São Paulo, Brazil, 17 November 2023) (ID: PsbkocsfDyo)
#
# ⏳ Processing: Quantum Theory &amp; The New Observables: Chapter 1 of Physical Principles of Quantum Biology
#
# ⏳ Processing: Quantum Biology: From Photons to Physiology
#
# ⏳ Processing: FULL LECTURE - Physical Foundations of Quantum Biology
#
# ⏳ Processing: A Template for Quantum Biology
#
# ⏳ Processing: Quantum Biology for Health and Medicine (Resonance Symposium, São Paulo, Brazil, 17 November 2023)
#
# 📦 Building vector database...
# ❓ Ask a question about the topic (or type 'exit'):  What quantum effects are found in biology
# 🔍 Top Relevant Chunks:
# 1. biology it's worth noting that Quantum biology is the study of biological processes that cannot be predicted or adequately described using only the principles of classical physics Quantum effects in biology include things like photosynthesis electron tunneling during cellular respiration and many fundamental aspects of molecular structure Quantum biology research has important implications for models of health and medicine with a variety of applications that I'll discuss today and it is
#
# 2. effects, quantum effects in biology. Uh but my view is that even when this approach is used at its best, it's essentially ad hoc because we're imagining a classical hay stack so to speak and going looking for quantum needles in it. Uh but really if we really believe quantum mechanics, we should begin with the quantum mechanical postulates first and then we can explore the full range of possible quantum states and effects at their most microscopic level at the level of atoms
#
# 3. fact that there is lawfulness and orderliness even on the microscopic scale in the organism which tells us immediately and this emphasis is schinger that the classical physicist expectation far from being trivial is wrong so we know that classical physics cannot predict the kind of effects we see at the microscop IC scale in biology so where is the Quantum in biology well biological Quantum effects are well established in redox co-actors these are special molecules found in
#
# 4. aspects of cellular respiration and other metabolic chemical reactions in living cells. So my view is that if we approach biology from first principles, we can learn new things not just about biology but also potentially physics. Now, a lot of work in quantum biology approaches biology from classical assumptions, classical biology, and then proposes to find effects that violate classical physics and say give organisms some selective advantage in order to identify possible so-called non-trivial
#
# 5. proven and I'm not going to dwell on areas of quantum biology which are not yet thoroughly established for the purpose of this foundational talk we're primarily going to talk about well let's not get ahead of ourselves some of you may be asking isn't biology just too warm and wet to sustain any Quantum effects well that's an interesting question because indeed according to classical physics the noisy statistical nature of the biological micro environment can only be overcome in the
#
#
# 🧠 OpenAI Summary:
# The speaker is discussing Quantum Biology, a field studying biological processes that cannot be adequately explained using only classical physics principles. This field includes the study of photosynthesis, electron tunneling during cellular respiration, and fundamental aspects of molecular structure. The speaker suggests that rather than looking for quantum effects within a classical framework, we should begin with quantum mechanical postulates to understand the full range of quantum states and effects at a microscopic level. The speaker also mentions that quantum effects in biology are well established in redox co-actors, special molecules found in aspects of cellular respiration and other metabolic chemical reactions in living cells. However, the speaker raises the question about the ability of the biological microenvironment to sustain quantum effects due to its warm and wet nature.
# ❓ Ask a question about the topic (or type 'exit'):  What proof does the author give for these effects?
# 🔍 Top Relevant Chunks:
# 1. challenging ones uh the electron deoization is first treated uh with Vanderwal's forces and dispersion. Uh now these kind of uh true quantum mechanical effects sometimes can be treated with relatively simple parameterized models. uh they're very important for things like the pi stacking of aromatic molecules and of course they're significant in any solvent system. Now in DNA in particular the electrostatic repulsion between stacked base pairs is balanced by the attractive London forces these
#
# 2. mechanics. Uh his trick was to focus only on observables, things that could conclusively be measured and counted in numbers. He based the new theory entirely on relationships between measurable quantities. And the reason why was because at that time they were trying to figure out the orbit of electrons around the nucleus in an atom. Uh but they couldn't measure the electron traveling in a circular orbit. the way we can observe the planets orbiting around the sun and eventually
#
# 3. abstract and find the book downloaded if you're a researcher a student or just curious to venture beyond classical biological explanations and uh finally in conclusion if you have any questions don't hesitate to reach out again I'm Dr. be uh this is my email address and bababcock@gmail.com. You can check out other YouTube videos on my YouTube channel at drbabcock. And an enormous thanks go out to my wife Brandy Babcock and collaborator on the book physical principles of quantum biology and on the
#
# 4. Newton's laws and the Hamiltonian principle and such. And from this he was able to effectively derive quantum mechanics in its textbook form as we still see it today. Now all of this in the form we see it today depends on this funny property called hermission symmetry. So this is a mathematical symmetry and in some sense the symmetry of nature that ensures the conservation of probabilities for example in our quantum system that probabilities should always add up to 100%. And if they don't
#
# 5. beautiful about the experiment is that he was able to show that the first spark could initiate a second spark in a distant uh metallic circuit. Now this is exciting because not just any color of light could produce the second spark. The first spark in the ultraviolet regime was necessary to overcome what's known as the work function in the metal in order to produce a second bright spark. Now I have to admit that the creation of sparks has come a long way since Herz's
#
#
# 🧠 OpenAI Summary:
# 1. The speaker discusses the use of Vanderwal's forces and dispersion in the electron deionization process. These quantum mechanical effects are important in various systems, including the pi stacking of aromatic molecules and solvent systems. In DNA, the electrostatic repulsion between stacked base pairs is balanced by attractive London forces.
#
# 2. The speaker then talks about a new theory based on observables, things that could be measured and counted. The theory was developed to understand the orbit of electrons around the nucleus in an atom, as this could not be directly observed like the planets orbiting the sun.
#
# 3. The speaker introduces themselves as Dr. Babcock and provides their email address for anyone with questions. They also mention their YouTube channel and thank their wife, Brandy Babcock, for her collaboration on a book about the physical principles of quantum biology.
#
# 4. The speaker explains that quantum mechanics in its current form depends on hermission symmetry, a mathematical symmetry that ensures the conservation of probabilities in a quantum system. This means that probabilities should always add up to 100%.
#
# 5. The speaker describes an experiment that demonstrated the initiation of a second spark in a distant metallic circuit by a first spark. This only worked with ultraviolet light, which was necessary to overcome the work function in the metal and produce a second spark.
